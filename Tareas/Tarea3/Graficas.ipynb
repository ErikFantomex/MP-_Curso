# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#df  = pd.read_csv("tiempo_sec.dat")
df1 = pd.read_csv("tiempos2.dat", sep=',',  names=['np','tiempo'])
df2 = pd.read_csv("tiempos1.dat", sep=',',  names=['np','tiempo','enc'])


max1 = df1['tiempo'].max()
max2 = df2['tiempo'].max()
print( max1, max2 )

maximo = np.max( [max1, max2 ])
print(maximo)

max1
# Out:
# 425.487 425.743
# 425.743
# 425.487

# %%
df1
# Out:
#     np    tiempo
# 0    1  425.4870
# 1    2  313.6050
# 2    3  230.7440
# 3    4  181.0990
# 4    5  148.9480
# 5    6  126.3100
# 6    7  109.5730
# 7    8   96.7669
# 8    9   86.7852
# 9   10   78.4486
# 10  11   71.6996
# 11  12   65.8294
# 12  13   61.0349
# 13  14   56.7647
# 14  15   53.0124

# %%
df2
# Out:
#     np    tiempo    enc
# 0    1  425.7430  14871
# 1    2  313.9220  14871
# 2    3  230.8840  14871
# 3    4  181.2170  14871
# 4    5  149.0360  14871
# 5    6  126.2090  14871
# 6    7  109.4660  14871
# 7    8   96.6657  14871
# 8    9   86.6938  14871
# 9   10   78.3756  14871
# 10  11   71.6203  14871
# 11  12   65.8011  14871
# 12  13   61.0243  14871
# 13  14   56.7588  14871
# 14  15   53.0010  14871

# %%
plt.plot(1,512.009,color='r',marker='*',markersize=20)
plt.text(1.5,512.009,'<--- secuencial',color='r')
plt.plot(df1['np'], df1['tiempo'],color='b',marker='.',label='paralela v1',linestyle='dashed')
plt.plot(df2['np'], df2['tiempo'],color='g',marker='.',label='paralela v2')
plt.xlabel("Numero de procesos")
plt.ylabel("Tiempo")
plt.legend()
plt.title("Primos gemelos en 2,000,000")
#plt.axis([0.5, 10.5, -0.1, maximo+0.5])
# Out:
# Text(0.5, 1.0, 'Primos gemelos en 2,000,000')
